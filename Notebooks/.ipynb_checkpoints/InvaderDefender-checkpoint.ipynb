# %% [markdown]
# # Invader Defender

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog

# %%
actions = [[-1, 0], [0, 1], [1, 0], [0, -1]] #up, right, down, left = (clockwise from up) 
action_count = len(actions) 
gridSize = 6 
state_count = gridSize*gridSize

# %%
class Invader_Defender():
    def __init__(self, gridSize):
        self.valueMap = np.zeros((gridSize, gridSize))
        self.states = [[i, j] for i in range(gridSize) for j in range(gridSize)]
        self.size = gridSize
        
        # deterministic transition ?
        self.transition_prob = 1 
        
        # initialize defender and invader states
        self.new_state = [0, 0, 0, 0]
        self.new_defender_state = [0, 0]
        self.new_invader_state = [0, 0]
        
        # set territory state
        self.territory_state = [4, 4]

        # create a list of all possible states in the game
        self.game_state_list = []
        for defender_state in self.states:
            for invader_state in self.states:
                combined_states = defender_state + invader_state
                self.game_state_list.append(combined_states)
        
        # create 2 lists of states representing defender and invader victory
        self.defender_won = []
        self.invader_won = []
        
        # create states representing defender victory
        for defender_state in self.states:
            for invader_state in self.states:
                distance = np.linalg.norm(np.array(defender_state) - np.array(invader_state))
                # if the invader is not at territory and within the capture range of defender = defender won
                if invader_state != self.territory_state and distance <= np.sqrt(2):
                    combined_states = defender_state + invader_state
                    self.defender_won.append(combined_states)
           
        # create states representing invader victory
        for defender_state in self.states:
            distance = np.linalg.norm(np.array(defender_state) - np.array(self.territory_state))
            # if the invader is at territory, and outside of the defender's capture range = invader won
            if distance > np.sqrt(2):
                combined_states = defender_state + self.territory_state
                self.invader_won.append(combined_states)
    
    def possible_states(self):
        """
        A function that returns a list of all possible states in the game
        """
        return self.game_state_list
    
    def terminal_check(self, state):
        """
        A function that checks whether the game is at a terminal state.
        Terminal state happens when either the invader or defender has won.
        """
        if state in self.defender_won:
            status = "Defender Won"
            terminal_check = True
        elif state in self.invader_won:
            status = "Invader Won"
            terminal_check = True
        else:
            terminal_check = False
            status = "Game in Progress"

        return terminal_check, status
    
#     def transition_probability(self, transition):
#         """
#         A function that returns the transition probability...?
#         """
#         return self.transition_prob, reward

    def next_state(self, current_state, defender_action, invader_action):
        """
        A function that returns the next state
        Input: current state [0,0] , defender_action [0, 1], invader_action [0,-1]
        Output: next state array([x1,y1,x2,y2]) and reward (int)
            - If the action takes the agent off grid, the agent remains in original state
            - If defender won, reward is calculated based on manhattan distance between invader captured state
            and territory
            - If defender loss, reward is -100
        """
        defender_state = []
        invader_state = []
        
        # deconstruct current state [0,0,1,1] in to defender [0,0] and invader [1,1] state
        for i in range(4):
            if i < 2:
                defender_state.append(current_state[i])
            else:
                invader_state.append(current_state[i])
                
        # get next state: state: [0, 0], action: [0, 1], new_state = [0, 1]
        self.new_defender_state = list(np.array(defender_state) + np.array(defender_action))
        self.new_invader_state = list(np.array(invader_state) + np.array(invader_action))

        # if new defender states results in off the grid, return to original state
        if -1 in self.new_defender_state or self.size in self.new_defender_state:
            self.new_defender_state = defender_state
        
        # if new invader states results in off the grid, return to original state
        if -1 in self.new_invader_state or self.size in self.new_invader_state:
            self.new_invader_state = invader_state
       
        # combine the defender and invader state
        self.new_state = self.new_defender_state
        self.new_state.extend(self.new_invader_state)
        
        # calculate rewards
        terminal, status = self.terminal_check(self.new_state)
        if terminal == True:
            if status == "Defender Won":
                # defender reward if defender won (manhattan distance between invader captured state and territory)
                distance_to_territory = sum(abs(np.array(self.new_invader_state) - np.array(self.territory_state)))
                self.reward = distance_to_territory
            else:
                # defender reward if invader won
                self.reward = -100
        else:
            self.reward = 0
            
        return self.new_state, self.reward

# %% [markdown]
# ## Testing

# %%
invader_defender = Invader_Defender(6)

# %%
next_state, reward = invader_defender.next_state([2,1,0,0], [-1, 0], [-1, 0])

# %%
next_state
# Out:
# [1, 1, 0, 0]

# %%
reward
# Out:
# 8

# %%
invader_defender.terminal_check([1, 1, 0, 0])
# Out:
# (True, 'Defender Won')

# %% [markdown]
# ## Value Iteration

# %%
invader_defender = Invader_Defender(6)

# %%
k = 0
U = {}
gamma = 0.9
state_list = []
listofzeros = [0.0] * len(invader_defender.game_state_list)

# convert game_state_list in to a state list of tuples in order to make a dictionary
for state in invader_defender.game_state_list:
    state_list.append(tuple(state))
    
# initiate params
G = dict(zip(state_list, listofzeros))
U[k] = dict(zip(state_list, listofzeros))

# %%
def calculate_payoff(state):
    """
    A function calculates the payoff of a specific state by iterating over every defender/invader action
    Input: state (ie. [0,0,1,1])
    Output: payoff = 4x4 matrix where each element represent the defender's payoff 
    when defender take i, and invader take action j
    """
    payoff = np.zeros([4,4])
    for i in range(action_count):
        defender_action = actions[i]
        for j in range(action_count):
            invader_action = actions[j]
            next_state, reward = invader_defender.next_state(state, defender_action, invader_action)
            payoff[i, j] = reward + gamma*invader_defender.transition_prob*U[k][tuple(next_state)]
    return payoff

# %%
def calculate_value(G_state):
    
    c = [0, 0, 0, 0, -1]
    defender_q = -1*G_state     
    v_coeff = np.ones((4,1))
    Aub = np.concatenate((defender_q,v_coeff),1)
    b = [0, 0, 0, 0]
    Aeq = [[1, 1, 1, 1, 0]]
    beq = [[1]]
    bounds = ((0,1),(0,1),(0,1),(0,1),(None, None))
    defender_solution = linprog(c, A_ub=Aub, b_ub=b, A_eq=Aeq, b_eq=beq, bounds=bounds)
    
    invader_q = np.transpose(defender_q)
    Aub = np.concatenate((invader_q,v_coeff),1)
    invader_solution = linprog(c, A_ub=Aub, b_ub=b, A_eq=Aeq, b_eq=beq, bounds=bounds)
    
    defender_value = defender_solution['fun']
    invader_value = invader_solution['fun']
    
    return defender_value, invader_value

# %%
# to remove warnings
import warnings
warnings.filterwarnings('ignore')

for state in invader_defender.game_state_list:
    
    # Build G dictionary {state: payoff (4x4)}
    G[tuple(state)] = calculate_payoff(state)
    defender_value, invader_value = calculate_value(G[tuple(state)])
    # calculate value of game
    print("state: ", state)
    print("defender value: ", defender_value)
    print("invader value: ", invader_value)
    print("---------------------")
    
    # calculate delta
    
    # if delta small enough, break
# Out:
# state:  [0, 0, 0, 0]
# defender value:  -7.999999999970426
# invader value:  -6.999999999991143
# ---------------------
# state:  [0, 0, 0, 1]
# defender value:  -7.999999998400379
# invader value:  -5.999999949372199
# ---------------------
# state:  [0, 0, 0, 2]
# defender value:  -6.999999999994232
# invader value:  3.843403593668384e-09
# ---------------------
# state:  [0, 0, 0, 3]
# defender value:  6.252411107099929e-12
# invader value:  6.2524111070998805e-12
# ---------------------
# state:  [0, 0, 0, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 0, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 1, 0]
# defender value:  -7.99999999840037
# invader value:  -5.999999949372178
# ---------------------
# state:  [0, 0, 1, 1]
# defender value:  -6.999999998794923
# invader value:  -2.4999999248691247
# ---------------------
# state:  [0, 0, 1, 2]
# defender value:  -5.99999998646847
# invader value:  1.8120511546922903e-09
# ---------------------
# state:  [0, 0, 1, 3]
# defender value:  5.663097509994808e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [0, 0, 1, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 1, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 2, 0]
# defender value:  -6.999999999993851
# invader value:  3.843403593684425e-09
# ---------------------
# state:  [0, 0, 2, 1]
# defender value:  -5.999999986468463
# invader value:  1.8120511546774486e-09
# ---------------------
# state:  [0, 0, 2, 2]
# defender value:  1.962267545188343e-12
# invader value:  1.9622675452056104e-12
# ---------------------
# state:  [0, 0, 2, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 2, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 3, 0]
# defender value:  6.2524111070999305e-12
# invader value:  6.2524111070998845e-12
# ---------------------
# state:  [0, 0, 3, 1]
# defender value:  5.663097509994836e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [0, 0, 3, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 3, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 3, 4]
# defender value:  -3.1323388327564317e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 0, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 0, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 0, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 0, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 0, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 0, 0]
# defender value:  -6.9999999732865295
# invader value:  -6.999999999924653
# ---------------------
# state:  [0, 1, 0, 1]
# defender value:  -6.9999999999575895
# invader value:  -5.999999999950974
# ---------------------
# state:  [0, 1, 0, 2]
# defender value:  -6.9999999999083595
# invader value:  -4.99999999997952
# ---------------------
# state:  [0, 1, 0, 3]
# defender value:  9.348254123924707e-11
# invader value:  6.674240189571528e-11
# ---------------------
# state:  [0, 1, 0, 4]
# defender value:  5.663097509994808e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [0, 1, 0, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 1, 0]
# defender value:  -5.999999999778495
# invader value:  -5.999999999992765
# ---------------------
# state:  [0, 1, 1, 1]
# defender value:  -6.999999999798584
# invader value:  -4.999999972967689
# ---------------------
# state:  [0, 1, 1, 2]
# defender value:  -5.9999999999108935
# invader value:  -1.9999999999458153
# ---------------------
# state:  [0, 1, 1, 3]
# defender value:  2.2196258953182486e-11
# invader value:  7.320402833191508e-11
# ---------------------
# state:  [0, 1, 1, 4]
# defender value:  4.564344376189428e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [0, 1, 1, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 2, 0]
# defender value:  1.7530151039547938e-10
# invader value:  1.3442635928783775e-10
# ---------------------
# state:  [0, 1, 2, 1]
# defender value:  -5.999999844137573
# invader value:  1.4438145097422353e-09
# ---------------------
# state:  [0, 1, 2, 2]
# defender value:  2.2196258953470962e-11
# invader value:  7.32040283309209e-11
# ---------------------
# state:  [0, 1, 2, 3]
# defender value:  9.519080905230273e-13
# invader value:  9.51908090506141e-13
# ---------------------
# state:  [0, 1, 2, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 3, 0]
# defender value:  6.2524111070999305e-12
# invader value:  6.2524111070998845e-12
# ---------------------
# state:  [0, 1, 3, 1]
# defender value:  5.663097509994836e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [0, 1, 3, 2]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [0, 1, 3, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 3, 4]
# defender value:  -3.1323388327564317e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 1, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 1, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 1, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 1, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 1, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 0, 0]
# defender value:  5.943729964528926e-09
# invader value:  -6.999999999455994
# ---------------------
# state:  [0, 2, 0, 1]
# defender value:  -5.9999999999875016
# invader value:  -5.999999998705611
# ---------------------
# state:  [0, 2, 0, 2]
# defender value:  -5.999999999984365
# invader value:  -4.999999999983693
# ---------------------
# state:  [0, 2, 0, 3]
# defender value:  -5.9999999999451115
# invader value:  -4.0000000000000515
# ---------------------
# state:  [0, 2, 0, 4]
# defender value:  3.567410014670812e-11
# invader value:  1.884398459439653e-11
# ---------------------
# state:  [0, 2, 0, 5]
# defender value:  4.564344376189428e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [0, 2, 1, 0]
# defender value:  9.949906984696e-11
# invader value:  2.0477547797208716e-10
# ---------------------
# state:  [0, 2, 1, 1]
# defender value:  -4.999999999944235
# invader value:  -2.91666666623553
# ---------------------
# state:  [0, 2, 1, 2]
# defender value:  -5.999999999964204
# invader value:  -3.999999933574476
# ---------------------
# state:  [0, 2, 1, 3]
# defender value:  -4.999999999990231
# invader value:  -1.4999999999839022
# ---------------------
# state:  [0, 2, 1, 4]
# defender value:  1.0980331285341629e-11
# invader value:  2.3526791920693427e-11
# ---------------------
# state:  [0, 2, 1, 5]
# defender value:  2.022440236317782e-12
# invader value:  2.022440236317792e-12
# ---------------------
# state:  [0, 2, 2, 0]
# defender value:  3.8033808528577725e-12
# invader value:  3.803380852849055e-12
# ---------------------
# state:  [0, 2, 2, 1]
# defender value:  2.180466659191372e-11
# invader value:  1.192078154560174e-10
# ---------------------
# state:  [0, 2, 2, 2]
# defender value:  -4.999999999990387
# invader value:  2.5163422939293594e-10
# ---------------------
# state:  [0, 2, 2, 3]
# defender value:  1.0980331285341797e-11
# invader value:  2.3526791921647748e-11
# ---------------------
# state:  [0, 2, 2, 4]
# defender value:  3.517189593456144e-13
# invader value:  3.517189593445917e-13
# ---------------------
# state:  [0, 2, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 3, 1]
# defender value:  5.663097509994836e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [0, 2, 3, 2]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [0, 2, 3, 3]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [0, 2, 3, 4]
# defender value:  -3.1323388327564317e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 2, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 2, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 2, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 2, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 2, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 0, 0]
# defender value:  6.726152918865301e-12
# invader value:  6.7261529189321436e-12
# ---------------------
# state:  [0, 3, 0, 1]
# defender value:  1.0966347220229057e-10
# invader value:  1.583677526895833e-10
# ---------------------
# state:  [0, 3, 0, 2]
# defender value:  -4.99999999999559
# invader value:  -4.999999999701807
# ---------------------
# state:  [0, 3, 0, 3]
# defender value:  -4.999999999992713
# invader value:  -3.9999999999951346
# ---------------------
# state:  [0, 3, 0, 4]
# defender value:  -4.99999994084101
# invader value:  -2.99999999996938
# ---------------------
# state:  [0, 3, 0, 5]
# defender value:  5.216642955576924e-10
# invader value:  -3.999999999987434
# ---------------------
# state:  [0, 3, 1, 0]
# defender value:  6.2524111070998805e-12
# invader value:  6.252411107099929e-12
# ---------------------
# state:  [0, 3, 1, 1]
# defender value:  2.208523103428617e-11
# invader value:  8.14886853676094e-11
# ---------------------
# state:  [0, 3, 1, 2]
# defender value:  -3.9999999999935913
# invader value:  -2.399999999869373
# ---------------------
# state:  [0, 3, 1, 3]
# defender value:  -4.999999999984103
# invader value:  -2.999999986579816
# ---------------------
# state:  [0, 3, 1, 4]
# defender value:  -3.9999999215249087
# invader value:  -1.3333333333308248
# ---------------------
# state:  [0, 3, 1, 5]
# defender value:  3.020996815999179e-13
# invader value:  1.4104888806377459e-11
# ---------------------
# state:  [0, 3, 2, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 2, 1]
# defender value:  2.4419321374183255e-12
# invader value:  2.441932135652217e-12
# ---------------------
# state:  [0, 3, 2, 2]
# defender value:  1.9290782172689732e-11
# invader value:  4.6446882336807184e-11
# ---------------------
# state:  [0, 3, 2, 3]
# defender value:  -3.9999998848483838
# invader value:  1.6656771506259307e-10
# ---------------------
# state:  [0, 3, 2, 4]
# defender value:  4.401096284462296e-12
# invader value:  4.781328166095135e-12
# ---------------------
# state:  [0, 3, 2, 5]
# defender value:  1.2085854331691816e-12
# invader value:  1.2085854331691812e-12
# ---------------------
# state:  [0, 3, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 3, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 3, 2]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [0, 3, 3, 3]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [0, 3, 3, 4]
# defender value:  -4.909137985009693e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [0, 3, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 3, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 3, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 3, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 3, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 0, 1]
# defender value:  6.2524111070998805e-12
# invader value:  6.252411107099929e-12
# ---------------------
# state:  [0, 4, 0, 2]
# defender value:  5.223856004209018e-11
# invader value:  8.187393347403886e-11
# ---------------------
# state:  [0, 4, 0, 3]
# defender value:  -3.9999999831974944
# invader value:  -3.999999999987502
# ---------------------
# state:  [0, 4, 0, 4]
# defender value:  -3.9999999999971756
# invader value:  -2.999999994341745
# ---------------------
# state:  [0, 4, 0, 5]
# defender value:  -3.9999999944392113
# invader value:  -3.999999999998015
# ---------------------
# state:  [0, 4, 1, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 1, 1]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [0, 4, 1, 2]
# defender value:  8.533526134191885e-12
# invader value:  3.744240609418785e-11
# ---------------------
# state:  [0, 4, 1, 3]
# defender value:  -2.9999999804701107
# invader value:  -1.8749999999617937
# ---------------------
# state:  [0, 4, 1, 4]
# defender value:  -3.9999999999659623
# invader value:  -1.9999999998855256
# ---------------------
# state:  [0, 4, 1, 5]
# defender value:  -2.9999999918275573
# invader value:  -2.9999999775251087
# ---------------------
# state:  [0, 4, 2, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 2, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 2, 2]
# defender value:  6.030496332183893e-13
# invader value:  6.030496332247036e-13
# ---------------------
# state:  [0, 4, 2, 3]
# defender value:  1.2179997658150377e-11
# invader value:  1.3961542657887497e-11
# ---------------------
# state:  [0, 4, 2, 4]
# defender value:  -2.99999998511027
# invader value:  2.8380368424999142e-11
# ---------------------
# state:  [0, 4, 2, 5]
# defender value:  1.1195708556889062e-11
# invader value:  3.4816106294308468e-12
# ---------------------
# state:  [0, 4, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 3, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 3, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 3, 3]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [0, 4, 3, 4]
# defender value:  -4.909137985009693e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [0, 4, 3, 5]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [0, 4, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 4, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 4, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 4, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 4, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 0, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 0, 2]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [0, 5, 0, 3]
# defender value:  -3.999999909836211
# invader value:  6.374532544737021e-11
# ---------------------
# state:  [0, 5, 0, 4]
# defender value:  -4.99999999997793
# invader value:  -2.999999999992791
# ---------------------
# state:  [0, 5, 0, 5]
# defender value:  -4.999999959998025
# invader value:  -3.9999999751910855
# ---------------------
# state:  [0, 5, 1, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 1, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 1, 2]
# defender value:  4.564344376189469e-12
# invader value:  4.564344376189428e-12
# ---------------------
# state:  [0, 5, 1, 3]
# defender value:  -2.999999974860552
# invader value:  7.91982315090971e-11
# ---------------------
# state:  [0, 5, 1, 4]
# defender value:  -3.99999999996231
# invader value:  -1.3333333333321034
# ---------------------
# state:  [0, 5, 1, 5]
# defender value:  -4.999999999913335
# invader value:  -2.999999999400952
# ---------------------
# state:  [0, 5, 2, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 2, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 2, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 2, 3]
# defender value:  1.208585433189472e-12
# invader value:  1.2085854331691824e-12
# ---------------------
# state:  [0, 5, 2, 4]
# defender value:  -2.99999996605355
# invader value:  2.6739395457638846e-11
# ---------------------
# state:  [0, 5, 2, 5]
# defender value:  -3.9999999007096427
# invader value:  2.6885424443346374e-10
# ---------------------
# state:  [0, 5, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 3, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 3, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 3, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 3, 4]
# defender value:  -4.909137985009693e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [0, 5, 3, 5]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [0, 5, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 5, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 5, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [0, 5, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [0, 5, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 0, 0]
# defender value:  -6.9999999732865295
# invader value:  -6.999999999924651
# ---------------------
# state:  [1, 0, 0, 1]
# defender value:  -5.999999999963599
# invader value:  -5.9999999999924825
# ---------------------
# state:  [1, 0, 0, 2]
# defender value:  1.7530151039342342e-10
# invader value:  1.3442635929380273e-10
# ---------------------
# state:  [1, 0, 0, 3]
# defender value:  6.252411107099929e-12
# invader value:  6.2524111070998805e-12
# ---------------------
# state:  [1, 0, 0, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 0, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 1, 0]
# defender value:  -6.9999999999557865
# invader value:  -5.999999999951009
# ---------------------
# state:  [1, 0, 1, 1]
# defender value:  -6.999999999798568
# invader value:  -4.999999972967702
# ---------------------
# state:  [1, 0, 1, 2]
# defender value:  -5.999999844137569
# invader value:  1.4438145097497421e-09
# ---------------------
# state:  [1, 0, 1, 3]
# defender value:  5.663097509994808e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [1, 0, 1, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 1, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 2, 0]
# defender value:  -6.999999999908388
# invader value:  -4.999999999979556
# ---------------------
# state:  [1, 0, 2, 1]
# defender value:  -5.999999999910891
# invader value:  -1.999999999945815
# ---------------------
# state:  [1, 0, 2, 2]
# defender value:  2.219625895325468e-11
# invader value:  7.320402832810245e-11
# ---------------------
# state:  [1, 0, 2, 3]
# defender value:  4.564344376189428e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 0, 2, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 3, 0]
# defender value:  9.348254124024023e-11
# invader value:  6.674240189366394e-11
# ---------------------
# state:  [1, 0, 3, 1]
# defender value:  2.2196258953182133e-11
# invader value:  7.32040283299259e-11
# ---------------------
# state:  [1, 0, 3, 2]
# defender value:  9.519080905230273e-13
# invader value:  9.51908090506141e-13
# ---------------------
# state:  [1, 0, 3, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 3, 4]
# defender value:  -3.1323388327564317e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 0, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 4, 0]
# defender value:  5.663097509994836e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [1, 0, 4, 1]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 0, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 0, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 0, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 0, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 0, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 0, 0]
# defender value:  -3.4999999999855294
# invader value:  -6.999999999860435
# ---------------------
# state:  [1, 1, 0, 1]
# defender value:  -5.999999999991443
# invader value:  -5.999999992111697
# ---------------------
# state:  [1, 1, 0, 2]
# defender value:  -2.916666666665417
# invader value:  -4.99999999853848
# ---------------------
# state:  [1, 1, 0, 3]
# defender value:  5.994497980119675e-11
# invader value:  8.217125455837328e-12
# ---------------------
# state:  [1, 1, 0, 4]
# defender value:  5.663097509994808e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [1, 1, 0, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 1, 0]
# defender value:  -5.999999999990632
# invader value:  -5.999999992111717
# ---------------------
# state:  [1, 1, 1, 1]
# defender value:  -4.374999999997687
# invader value:  -4.374999999998236
# ---------------------
# state:  [1, 1, 1, 2]
# defender value:  -5.999999999993643
# invader value:  -3.999999989597218
# ---------------------
# state:  [1, 1, 1, 3]
# defender value:  3.691838614009447e-11
# invader value:  3.595889693923854e-11
# ---------------------
# state:  [1, 1, 1, 4]
# defender value:  4.564344376189428e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 1, 1, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 2, 0]
# defender value:  -2.9166666666654084
# invader value:  -4.999999998538481
# ---------------------
# state:  [1, 1, 2, 1]
# defender value:  -5.999999999993628
# invader value:  -3.9999999895972205
# ---------------------
# state:  [1, 1, 2, 2]
# defender value:  -2.500000000002583
# invader value:  -1.4999999999973377
# ---------------------
# state:  [1, 1, 2, 3]
# defender value:  1.631585590790444e-11
# invader value:  1.6315855907974946e-11
# ---------------------
# state:  [1, 1, 2, 4]
# defender value:  2.022440236317782e-12
# invader value:  2.022440236317792e-12
# ---------------------
# state:  [1, 1, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 3, 0]
# defender value:  5.994497980004224e-11
# invader value:  8.217125455946797e-12
# ---------------------
# state:  [1, 1, 3, 1]
# defender value:  3.6918386141853926e-11
# invader value:  3.595889693898972e-11
# ---------------------
# state:  [1, 1, 3, 2]
# defender value:  1.631585590790462e-11
# invader value:  1.631585590790462e-11
# ---------------------
# state:  [1, 1, 3, 3]
# defender value:  3.517189593456144e-13
# invader value:  3.517189593445917e-13
# ---------------------
# state:  [1, 1, 3, 4]
# defender value:  -3.1323388327564317e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 1, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 4, 0]
# defender value:  5.663097509994836e-12
# invader value:  5.663097510011314e-12
# ---------------------
# state:  [1, 1, 4, 1]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 1, 4, 2]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [1, 1, 4, 3]
# defender value:  -3.1300295688652113e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 1, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 1, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 1, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 1, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 0, 0]
# defender value:  2.7257290061637975e-09
# invader value:  -6.9999999958562835
# ---------------------
# state:  [1, 2, 0, 1]
# defender value:  -2.9999999999797917
# invader value:  -5.999999992526166
# ---------------------
# state:  [1, 2, 0, 2]
# defender value:  -4.999999933478935
# invader value:  -4.999999999890267
# ---------------------
# state:  [1, 2, 0, 3]
# defender value:  -2.40000000000029
# invader value:  -3.9999999999919824
# ---------------------
# state:  [1, 2, 0, 4]
# defender value:  2.2648171944921095e-11
# invader value:  5.041700227714563e-12
# ---------------------
# state:  [1, 2, 0, 5]
# defender value:  4.564344376189428e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 2, 1, 0]
# defender value:  5.5934259696325554e-09
# invader value:  -5.999999999999208
# ---------------------
# state:  [1, 2, 1, 1]
# defender value:  -4.9999999836312075
# invader value:  -4.999999999973833
# ---------------------
# state:  [1, 2, 1, 2]
# defender value:  -3.599999999997915
# invader value:  -3.59999999999747
# ---------------------
# state:  [1, 2, 1, 3]
# defender value:  -4.999999999992599
# invader value:  -2.9999999930776142
# ---------------------
# state:  [1, 2, 1, 4]
# defender value:  1.201123228610205e-11
# invader value:  1.5479240302436585e-11
# ---------------------
# state:  [1, 2, 1, 5]
# defender value:  2.022440236317782e-12
# invader value:  2.022440236317792e-12
# ---------------------
# state:  [1, 2, 2, 0]
# defender value:  1.1025540771971051e-10
# invader value:  2.0493891730378327e-11
# ---------------------
# state:  [1, 2, 2, 1]
# defender value:  -2.39999999999772
# invader value:  -2.3999999999609756
# ---------------------
# state:  [1, 2, 2, 2]
# defender value:  -4.999999875166843
# invader value:  -2.999999993077608
# ---------------------
# state:  [1, 2, 2, 3]
# defender value:  -2.0000000103268936
# invader value:  -0.9999999999939886
# ---------------------
# state:  [1, 2, 2, 4]
# defender value:  5.906317301371007e-12
# invader value:  5.90631730133682e-12
# ---------------------
# state:  [1, 2, 2, 5]
# defender value:  5.797592201802911e-13
# invader value:  5.797592201783246e-13
# ---------------------
# state:  [1, 2, 3, 0]
# defender value:  2.4419321374183255e-12
# invader value:  2.441932135652217e-12
# ---------------------
# state:  [1, 2, 3, 1]
# defender value:  2.4707532049835375e-11
# invader value:  4.278851754434431e-12
# ---------------------
# state:  [1, 2, 3, 2]
# defender value:  1.2011232286064021e-11
# invader value:  1.5479240302002742e-11
# ---------------------
# state:  [1, 2, 3, 3]
# defender value:  5.906317301422348e-12
# invader value:  5.9063173013881204e-12
# ---------------------
# state:  [1, 2, 3, 4]
# defender value:  -6.204417424271469e-08
# invader value:  99.99999997619027
# ---------------------
# state:  [1, 2, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 4, 1]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [1, 2, 4, 2]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [1, 2, 4, 3]
# defender value:  -4.9091415377233716e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [1, 2, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 2, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 2, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 2, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 0, 0]
# defender value:  6.726152918865301e-12
# invader value:  6.7261529189321436e-12
# ---------------------
# state:  [1, 3, 0, 1]
# defender value:  1.8845279360260194e-10
# invader value:  2.1261164869975754e-11
# ---------------------
# state:  [1, 3, 0, 2]
# defender value:  -2.5000000000001643
# invader value:  -4.999999998583106
# ---------------------
# state:  [1, 3, 0, 3]
# defender value:  -3.999999983514974
# invader value:  -3.9999999999670863
# ---------------------
# state:  [1, 3, 0, 4]
# defender value:  -1.874999999274106
# invader value:  -2.9999999999882876
# ---------------------
# state:  [1, 3, 0, 5]
# defender value:  4.213163200803444e-10
# invader value:  -3.9999999999867515
# ---------------------
# state:  [1, 3, 1, 0]
# defender value:  6.2524111070998805e-12
# invader value:  6.252411107099929e-12
# ---------------------
# state:  [1, 3, 1, 1]
# defender value:  4.342807811701241e-11
# invader value:  9.159904199707972e-11
# ---------------------
# state:  [1, 3, 1, 2]
# defender value:  -3.9999999938286845
# invader value:  -3.9999999999898312
# ---------------------
# state:  [1, 3, 1, 3]
# defender value:  -2.8124999999979465
# invader value:  -2.812499999982986
# ---------------------
# state:  [1, 3, 1, 4]
# defender value:  -3.9999999939160737
# invader value:  -1.9999999999975926
# ---------------------
# state:  [1, 3, 1, 5]
# defender value:  1.5775485778498668e-10
# invader value:  -2.999999977144844
# ---------------------
# state:  [1, 3, 2, 0]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [1, 3, 2, 1]
# defender value:  7.263987777263771e-11
# invader value:  1.9174662228664034e-11
# ---------------------
# state:  [1, 3, 2, 2]
# defender value:  -1.874999990319092
# invader value:  -1.8750000000011129
# ---------------------
# state:  [1, 3, 2, 3]
# defender value:  -3.9999999184791424
# invader value:  -1.9999999953650052
# ---------------------
# state:  [1, 3, 2, 4]
# defender value:  -1.4999999987620716
# invader value:  -0.7499999997922951
# ---------------------
# state:  [1, 3, 2, 5]
# defender value:  2.993766489901141e-12
# invader value:  4.2813738061177254e-13
# ---------------------
# state:  [1, 3, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 3, 1]
# defender value:  6.030496332183893e-13
# invader value:  6.030496332247036e-13
# ---------------------
# state:  [1, 3, 3, 2]
# defender value:  1.359303508358085e-11
# invader value:  3.3613394840372656e-12
# ---------------------
# state:  [1, 3, 3, 3]
# defender value:  4.446607078126547e-12
# invader value:  9.308537863434549e-13
# ---------------------
# state:  [1, 3, 3, 4]
# defender value:  -1.6168364425084292e-09
# invader value:  99.99999997776702
# ---------------------
# state:  [1, 3, 3, 5]
# defender value:  2.759935295356047e-12
# invader value:  2.759935295356045e-12
# ---------------------
# state:  [1, 3, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 4, 2]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [1, 3, 4, 3]
# defender value:  -4.9091415377233716e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [1, 3, 4, 4]
# defender value:  2.2033108973543387e-12
# invader value:  2.2033108973543387e-12
# ---------------------
# state:  [1, 3, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 3, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 3, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 3, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 0, 1]
# defender value:  6.2524111070998805e-12
# invader value:  6.252411107099929e-12
# ---------------------
# state:  [1, 4, 0, 2]
# defender value:  8.993316492862114e-11
# invader value:  1.408966376965318e-11
# ---------------------
# state:  [1, 4, 0, 3]
# defender value:  -1.9999999904845545
# invader value:  -3.99999999997275
# ---------------------
# state:  [1, 4, 0, 4]
# defender value:  -2.9999999997283524
# invader value:  -2.999999999996605
# ---------------------
# state:  [1, 4, 0, 5]
# defender value:  -1.9999999922241547
# invader value:  -3.999999999956316
# ---------------------
# state:  [1, 4, 1, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 1, 1]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [1, 4, 1, 2]
# defender value:  1.1571612770936089e-11
# invader value:  3.115254666472966e-11
# ---------------------
# state:  [1, 4, 1, 3]
# defender value:  -2.9999999982789527
# invader value:  -2.999999984926485
# ---------------------
# state:  [1, 4, 1, 4]
# defender value:  -2.6666666666660945
# invader value:  -1.9999999999812708
# ---------------------
# state:  [1, 4, 1, 5]
# defender value:  -2.9999999959098176
# invader value:  -2.9999999999952824
# ---------------------
# state:  [1, 4, 2, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 2, 1]
# defender value:  4.564344376189469e-12
# invader value:  4.564344376189428e-12
# ---------------------
# state:  [1, 4, 2, 2]
# defender value:  1.328924890500574e-11
# invader value:  9.77224626863947e-12
# ---------------------
# state:  [1, 4, 2, 3]
# defender value:  -1.3333333272847225
# invader value:  -1.3333333333347988
# ---------------------
# state:  [1, 4, 2, 4]
# defender value:  -2.999999970561889
# invader value:  -0.9999999881606491
# ---------------------
# state:  [1, 4, 2, 5]
# defender value:  -1.3333333283900513
# invader value:  -1.9999999911353887
# ---------------------
# state:  [1, 4, 3, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 3, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 3, 2]
# defender value:  1.208585433189472e-12
# invader value:  1.2085854331691824e-12
# ---------------------
# state:  [1, 4, 3, 3]
# defender value:  4.321730288217664e-12
# invader value:  1.7900032325014612e-12
# ---------------------
# state:  [1, 4, 3, 4]
# defender value:  -1.7362236093276806e-08
# invader value:  100.00000000006153
# ---------------------
# state:  [1, 4, 3, 5]
# defender value:  4.809421190427246e-12
# invader value:  2.3521923892759043e-12
# ---------------------
# state:  [1, 4, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 4, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 4, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 4, 3]
# defender value:  -4.9091415377233716e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [1, 4, 4, 4]
# defender value:  2.2033108973543387e-12
# invader value:  2.2033108973543387e-12
# ---------------------
# state:  [1, 4, 4, 5]
# defender value:  -4.909172623968061e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [1, 4, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 5, 2]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 4, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [1, 4, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 5, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 5, 0, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [1, 5, 0, 2]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [1, 5, 0, 3]
# defender value:  1.3398270382787121e-11
# invader value:  2.7425289683483472e-11
# ---------------------
# state:  [1, 5, 0, 4]
# defender value:  -2.9999999923271083
# invader value:  -2.9999999999978932
# ---------------------
# state:  [1, 5, 0, 5]
# defender value:  -3.9999999944392144
# invader value:  -3.9999999999982276
# ...
# ---------------------
# state:  [2, 1, 1, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 1, 2, 0]
# defender value:  -4.999999933478935
# invader value:  -4.9999999998902265
# ---------------------
# state:  [2, 1, 2, 1]
# defender value:  -3.599999999997915
# invader value:  -3.59999999999747
# ---------------------
# state:  [2, 1, 2, 2]
# defender value:  -4.999999999992599
# invader value:  -2.9999999930776142
# ---------------------
# state:  [2, 1, 2, 3]
# defender value:  1.201123228610205e-11
# invader value:  1.5479240302436585e-11
# ---------------------
# state:  [2, 1, 2, 4]
# defender value:  2.022440236317782e-12
# invader value:  2.022440236317792e-12
# ---------------------
# state:  [2, 1, 2, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 1, 3, 0]
# defender value:  -2.400000000000289
# invader value:  -3.9999999999918603
# ---------------------
# state:  [2, 1, 3, 1]
# defender value:  -4.999999875166843
# invader value:  -2.999999993077608
# ---------------------
# state:  [2, 1, 3, 2]
# defender value:  -2.0000000103268936
# invader value:  -0.9999999999939886
# ---------------------
# state:  [2, 1, 3, 3]
# defender value:  5.906317301371007e-12
# invader value:  5.90631730133682e-12
# ---------------------
# state:  [2, 1, 3, 4]
# defender value:  -4.909119333262879e-09
# invader value:  99.99999993682664
# ---------------------
# state:  [2, 1, 3, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 1, 4, 0]
# defender value:  2.2648171944763243e-11
# invader value:  5.041700227696693e-12
# ---------------------
# state:  [2, 1, 4, 1]
# defender value:  1.2011232286064021e-11
# invader value:  1.5479240302002742e-11
# ---------------------
# state:  [2, 1, 4, 2]
# defender value:  5.906317301422348e-12
# invader value:  5.9063173013881204e-12
# ---------------------
# state:  [2, 1, 4, 3]
# defender value:  -6.204417513089311e-08
# invader value:  99.99999997619027
# ---------------------
# state:  [2, 1, 4, 4]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 1, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [2, 1, 5, 0]
# defender value:  4.56434437618947e-12
# invader value:  4.564344376189469e-12
# ---------------------
# state:  [2, 1, 5, 1]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [2, 1, 5, 2]
# defender value:  5.797592201802908e-13
# invader value:  5.797592201783247e-13
# ---------------------
# state:  [2, 1, 5, 3]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 1, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [2, 1, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 2, 0, 0]
# defender value:  4.31929491333076e-12
# invader value:  4.319294913366342e-12
# ---------------------
# state:  [2, 2, 0, 1]
# defender value:  1.8845279360398165e-10
# invader value:  2.1261164869460278e-11
# ---------------------
# state:  [2, 2, 0, 2]
# defender value:  3.2650464006199157e-09
# invader value:  -4.999999999979636
# ---------------------
# state:  [2, 2, 0, 3]
# defender value:  4.2099518014679155e-11
# invader value:  1.2890960648980192e-11
# ---------------------
# state:  [2, 2, 0, 4]
# defender value:  6.030496332247036e-13
# invader value:  6.030496332183893e-13
# ---------------------
# state:  [2, 2, 0, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 2, 1, 0]
# defender value:  1.8845279359846267e-10
# invader value:  2.126116486982834e-11
# ---------------------
# state:  [2, 2, 1, 1]
# defender value:  -2.500000000282567
# invader value:  -3.500000000001263
# ---------------------
# state:  [2, 2, 1, 2]
# defender value:  -3.9999999938286797
# invader value:  -3.999999999989352
# ---------------------
# state:  [2, 2, 1, 3]
# defender value:  -1.8749999903190822
# invader value:  -1.8750000000011156
# ---------------------
# state:  [2, 2, 1, 4]
# defender value:  1.3593035083649325e-11
# invader value:  3.361339484322105e-12
# ---------------------
# state:  [2, 2, 1, 5]
# defender value:  2.022440236317782e-12
# invader value:  2.022440236317792e-12
# ---------------------
# state:  [2, 2, 2, 0]
# defender value:  3.26504640063489e-09
# invader value:  -4.999999999979672
# ---------------------
# state:  [2, 2, 2, 1]
# defender value:  -3.9999999938286845
# invader value:  -3.9999999999898312
# ---------------------
# state:  [2, 2, 2, 2]
# defender value:  -2.8124999999979465
# invader value:  -2.812499999982986
# ---------------------
# state:  [2, 2, 2, 3]
# defender value:  -3.999999918479151
# invader value:  -1.9999999953649825
# ---------------------
# state:  [2, 2, 2, 4]
# defender value:  4.446607078091175e-12
# invader value:  9.308537865107568e-13
# ---------------------
# state:  [2, 2, 2, 5]
# defender value:  5.797592201802911e-13
# invader value:  5.797592201783246e-13
# ---------------------
# state:  [2, 2, 3, 0]
# defender value:  4.209951801303406e-11
# invader value:  1.2890960648980192e-11
# ---------------------
# state:  [2, 2, 3, 1]
# defender value:  -1.874999990319092
# invader value:  -1.8750000000011129
# ---------------------
# state:  [2, 2, 3, 2]
# defender value:  -3.9999999184791424
# invader value:  -1.9999999953650052
# ---------------------
# state:  [2, 2, 3, 3]
# defender value:  -1.500000000885142
# invader value:  -0.4999999999973934
# ---------------------
# state:  [2, 2, 3, 4]
# defender value:  -1.6168328897947504e-09
# invader value:  99.99999997776699
# ---------------------
# state:  [2, 2, 3, 5]
# defender value:  2.203310897354339e-12
# invader value:  2.203310897354339e-12
# ---------------------
# state:  [2, 2, 4, 0]
# defender value:  6.030496332183893e-13
# invader value:  6.030496332247036e-13
# ---------------------
# state:  [2, 2, 4, 1]
# defender value:  1.359303508358085e-11
# invader value:  3.3613394840372656e-12
# ---------------------
# state:  [2, 2, 4, 2]
# defender value:  4.446607078126547e-12
# invader value:  9.308537863434549e-13
# ---------------------
# state:  [2, 2, 4, 3]
# defender value:  -1.616842659757367e-09
# invader value:  99.99999997776702
# ---------------------
# state:  [2, 2, 4, 4]
# defender value:  4.032864403258051e-12
# invader value:  4.032864400601295e-12
# ---------------------
# state:  [2, 2, 4, 5]
# defender value:  -3.129940751023241e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [2, 2, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 2, 5, 1]
# defender value:  2.022440236317792e-12
# invader value:  2.022440236317791e-12
# ---------------------
# state:  [2, 2, 5, 2]
# defender value:  5.797592201802908e-13
# invader value:  5.797592201783247e-13
# ---------------------
# state:  [2, 2, 5, 3]
# defender value:  2.2033108973543387e-12
# invader value:  2.2033108973543387e-12
# ---------------------
# state:  [2, 2, 5, 4]
# defender value:  -3.1301183867071813e-11
# invader value:  99.9999999989466
# ---------------------
# state:  [2, 2, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 3, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 3, 0, 1]
# defender value:  2.9748209937790503e-12
# invader value:  2.9748209955545155e-12
# ---------------------
# state:  [2, 3, 0, 2]
# defender value:  8.993316492527571e-11
# invader value:  1.4089663769543922e-11
# ---------------------
# state:  [2, 3, 0, 3]
# defender value:  1.4575596136682927e-09
# invader value:  -3.9999999999914473
# ---------------------
# state:  [2, 3, 0, 4]
# defender value:  8.129796714349903e-12
# invader value:  6.507236392620891e-12
# ---------------------
# state:  [2, 3, 0, 5]
# defender value:  9.519080914102304e-13
# invader value:  9.519080905188215e-13
# ---------------------
# state:  [2, 3, 1, 0]
# defender value:  6.2524111070998805e-12
# invader value:  6.252411107099929e-12
# ---------------------
# state:  [2, 3, 1, 1]
# defender value:  3.6341303064635244e-11
# invader value:  3.634130306492387e-11
# ---------------------
# state:  [2, 3, 1, 2]
# defender value:  -1.9999999977694194
# invader value:  -2.999999999998649
# ---------------------
# state:  [2, 3, 1, 3]
# defender value:  -2.9999999982789425
# invader value:  -2.999999984926503
# ---------------------
# state:  [2, 3, 1, 4]
# defender value:  -1.3333333327727346
# invader value:  -2.0000000000002522
# ---------------------
# state:  [2, 3, 1, 5]
# defender value:  6.249912842506909e-12
# invader value:  3.0786292187701007e-12
# ---------------------
# state:  [2, 3, 2, 0]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [2, 3, 2, 1]
# defender value:  1.1571612770936089e-11
# invader value:  3.115254666472966e-11
# ---------------------
# state:  [2, 3, 2, 2]
# defender value:  -2.9999999982789527
# invader value:  -2.999999984926485
# ---------------------
# state:  [2, 3, 2, 3]
# defender value:  -1.9999999999560085
# invader value:  -1.9999999973598115
# ---------------------
# state:  [2, 3, 2, 4]
# defender value:  -2.99999999295194
# invader value:  -0.999999999812954
# ---------------------
# state:  [2, 3, 2, 5]
# defender value:  5.392638377904349e-11
# invader value:  -1.9999999994207691
# ---------------------
# state:  [2, 3, 3, 0]
# defender value:  4.564344376189469e-12
# invader value:  4.564344376189428e-12
# ---------------------
# state:  [2, 3, 3, 1]
# defender value:  1.328924890500574e-11
# invader value:  9.77224626863947e-12
# ---------------------
# state:  [2, 3, 3, 2]
# defender value:  -1.3333333272847225
# invader value:  -1.3333333333347988
# ---------------------
# state:  [2, 3, 3, 3]
# defender value:  -2.9999999767909262
# invader value:  -0.9999999999971467
# ---------------------
# state:  [2, 3, 3, 4]
# defender value:  -1.000000003614268
# invader value:  -1.9910066040296215e-08
# ---------------------
# state:  [2, 3, 3, 5]
# defender value:  1.8216075063207945e-12
# invader value:  1.4523316703736191e-12
# ---------------------
# state:  [2, 3, 4, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 3, 4, 1]
# defender value:  1.208585433189472e-12
# invader value:  1.2085854331691824e-12
# ---------------------
# state:  [2, 3, 4, 2]
# defender value:  4.321730288217664e-12
# invader value:  1.7900032325014612e-12
# ---------------------
# state:  [2, 3, 4, 3]
# defender value:  -9.909558507104066e-09
# invader value:  2.317799490238398e-08
# ---------------------
# state:  [2, 3, 4, 4]
# defender value:  2.552546044100817e-12
# invader value:  2.5525460448797114e-12
# ---------------------
# state:  [2, 3, 4, 5]
# defender value:  6.955546267333129e-13
# invader value:  4.4612410472169915e-09
# ---------------------
# state:  [2, 3, 5, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 3, 5, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 3, 5, 2]
# defender value:  5.797592201802908e-13
# invader value:  5.797592201783247e-13
# ---------------------
# state:  [2, 3, 5, 3]
# defender value:  2.2033108973543387e-12
# invader value:  2.2033108973543387e-12
# ---------------------
# state:  [2, 3, 5, 4]
# defender value:  1.3485206883141856e-12
# invader value:  6.347046246823701e-13
# ---------------------
# state:  [2, 3, 5, 5]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 4, 0, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 4, 0, 1]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 4, 0, 2]
# defender value:  1.9622675452056104e-12
# invader value:  1.962267545188343e-12
# ---------------------
# state:  [2, 4, 0, 3]
# defender value:  3.081715155145975e-11
# invader value:  8.120979769980983e-12
# ---------------------
# state:  [2, 4, 0, 4]
# defender value:  3.4985538259954284e-10
# invader value:  -2.9999999998918727
# ---------------------
# state:  [2, 4, 0, 5]
# defender value:  4.213163200819652e-10
# invader value:  -3.9999999999867297
# ---------------------
# state:  [2, 4, 1, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# state:  [2, 4, 1, 1]
# defender value:  5.663097510011314e-12
# invader value:  5.663097509994808e-12
# ---------------------
# state:  [2, 4, 1, 2]
# defender value:  1.6315855907974946e-11
# invader value:  1.631585590790444e-11
# ---------------------
# state:  [2, 4, 1, 3]
# defender value:  -1.4999999997312248
# invader value:  -2.4999999999903597
# ---------------------
# state:  [2, 4, 1, 4]
# defender value:  -1.9999999999297544
# invader value:  -1.9999999901486785
# ---------------------
# state:  [2, 4, 1, 5]
# defender value:  -1.4999999982575627
# invader value:  -3.000000001024005
# ---------------------
# state:  [2, 4, 2, 0]
# defender value:  2.2436115337637674e-12
# invader value:  2.2436115337637674e-12
# ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-970f0209c003> in <module>
#       7     # Build G dictionary {state: payoff (4x4)}
#       8     G[tuple(state)] = calculate_payoff(state)
# ----> 9     defender_value, invader_value = calculate_value(G[tuple(state)])
#      10     # calculate value of game
#      11     print("state: ", state)
#
# <ipython-input-12-4da48875f610> in calculate_value(G_state)
#       9     beq = [[1]]
#      10     bounds = ((0,1),(0,1),(0,1),(0,1),(None, None))
# ---> 11     defender_solution = linprog(c, A_ub=Aub, b_ub=b, A_eq=Aeq, b_eq=beq, bounds=bounds)
#      12
#      13     invader_q = np.transpose(defender_q)
#
# ~/.local/lib/python3.5/site-packages/scipy/optimize/_linprog.py in linprog(c, A_ub, b_ub, A_eq, b_eq, bounds, method, callback, options, x0)
#     552             x, status, message, iteration = _linprog_ip(
#     553                 c, c0=c0, A=A, b=b, callback=callback,
# --> 554                 postsolve_args=postsolve_args, **solver_options)
#     555         elif meth == 'revised simplex':
#     556             x, status, message, iteration = _linprog_rs(
#
# ~/.local/lib/python3.5/site-packages/scipy/optimize/_linprog_ip.py in _linprog_ip(c, c0, A, b, callback, postsolve_args, maxiter, tol, disp, alpha0, beta, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec, **unknown_options)
#    1123                                             lstsq, sym_pos, cholesky,
#    1124                                             pc, ip, permc_spec, callback,
# -> 1125                                             postsolve_args)
#    1126
#    1127     return x, status, message, iteration
#
# ~/.local/lib/python3.5/site-packages/scipy/optimize/_linprog_ip.py in _ip_hsd(A, b, c, c0, alpha0, beta, maxiter, disp, tol, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec, callback, postsolve_args)
#     753             d_x, d_y, d_z, d_tau, d_kappa = _get_delta(
#     754                 A, b, c, x, y, z, tau, kappa, gamma, eta,
# --> 755                 sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec)
#     756
#     757             if ip:  # initial point
#
# ~/.local/lib/python3.5/site-packages/scipy/optimize/_linprog_ip.py in _get_delta(A, b, c, x, y, z, tau, kappa, gamma, eta, sparse, lstsq, sym_pos, cholesky, pc, ip, permc_spec)
#     263             try:
#     264                 # [4] Equation 8.28
# --> 265                 p, q = _sym_solve(Dinv, A, c, b, solve)
#     266                 # [4] Equation 8.29
#     267                 u, v = _sym_solve(Dinv, A, rhatd -
#
# ~/.local/lib/python3.5/site-packages/scipy/optimize/_linprog_ip.py in _sym_solve(Dinv, A, r1, r2, solve)
#     346     v = solve(r)
#     347     # [4] 8.32
# --> 348     u = Dinv * (A.T.dot(v) - r1)
#     349     return u, v
#     350
#
# KeyboardInterrupt:
